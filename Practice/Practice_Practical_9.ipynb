# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = sns.load_dataset("titanic")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
x_points = [10,20,30,40,45,47,50, 56,59,64]
y_points = [5,12,16,24,29,32,34,56,64,67]

# %%
plt.plot(x_points,y_points,'o')

# %%
plt.plot(x_points,y_points)

# %%
plt.plot(x_points,y_points, marker='o')
plt.title('Data_Representation')
# plt.grid()
plt.show()

# %%
plt.plot(x_points,y_points, marker='o')
plt.title("Data Representation")
plt.grid()

# %%
plt.plot(df["age"],df["survived"])

# %%
plt.plot(y_points, linestyle="dotted" )

# %%
plt.plot(y_points,linestyle="dashed")

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 210, 180, 200, 160, 220, 240, 310, 320, 330])

plt.plot(x, y)

plt.title("Sports Watch Data")

plt.show()

# %%
plt.scatter(x,y)

# %%
plt.bar(x,y, color="red", alpha=0.3, width=2)
# Out:
# <BarContainer object of 10 artists>

# %%
plt.barh(x,y)
# Out:
# <BarContainer object of 10 artists>

# %%
plt.hist( df["age"],bins=12)
# Out:
# (array([ 50.,  21., 108., 140., 144., 101.,  52.,  48.,  28.,  15.,   5.,
#           2.]),
#  array([ 0.42      ,  7.05166667, 13.68333333, 20.315     , 26.94666667,
#         33.57833333, 40.21      , 46.84166667, 53.47333333, 60.105     ,
#         66.73666667, 73.36833333, 80.        ]),
#  <BarContainer object of 12 artists>)

# %%
plt.pie(df["sex"].value_counts(), labels=["male","female"])
# Out:
# ([<matplotlib.patches.Wedge at 0x29a655dacb0>,
# ...
#  [Text(-0.4919454136803954, 0.9838646807152012, 'male'),
#   Text(0.4919455057964525, -0.9838646346559433, 'female')])

# %% [markdown]
# ## seaborn plots

# %%
sns.boxplot(x="sex",y="age", hue="survived", data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.histplot(df["fare"])
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Count'>

# %%
sns.histplot(x="age",data=df,kde=True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.kdeplot(df["age"], fill=True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.lineplot(x="age",y="fare",data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='fare'>

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
iris = sns.load_dataset("iris")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris_grp = iris.groupby("species")

# %%
setosa = iris_grp.get_group("setosa")

# %%
setosa
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
plt.figure(figsize=(10,7))
box = setosa.boxplot()
medians = setosa.median()
for i in range(len(medians)):
    box.annotate(medians[i],(i+1, medians[i]), ha="center", va="center", color="red", size=10)
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9592\3447076601.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   medians = setosa.median()

# %%
sns.scatterplot(x="sepal_length",y="sepal_width",data=iris)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.barplot(x="sex",y="age", hue="survived", data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.countplot(x="sex",data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
df1 = df[["fare","survived","sex"]]
sns.pairplot(df1)
plt.show()

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.catplot(x="sex", kind='count', hue="survived", data=df)
