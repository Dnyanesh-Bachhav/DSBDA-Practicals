# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Dell\\IPL Matches 2008-2020.csv")

# %%
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.describe()
# Out:
#                  id  neutral_venue  result_margin
# count  8.160000e+02     816.000000     799.000000
# mean   7.563496e+05       0.094363      17.321652
# std    3.058943e+05       0.292512      22.068427
# min    3.359820e+05       0.000000       1.000000
# 25%    5.012278e+05       0.000000       6.000000
# 50%    7.292980e+05       0.000000       8.000000
# 75%    1.082626e+06       0.000000      19.500000
# max    1.237181e+06       1.000000     146.000000

# %%
df.isna()
# Out:
#         id   city   date  player_of_match  venue  neutral_venue  team1  team2  \
# 0    False  False  False            False  False          False  False  False
# 1    False  False  False            False  False          False  False  False
# 2    False  False  False            False  False          False  False  False
# 3    False  False  False            False  False          False  False  False
# 4    False  False  False            False  False          False  False  False
# ..     ...    ...    ...              ...    ...            ...    ...    ...
# 811  False  False  False            False  False          False  False  False
# 812  False  False  False            False  False          False  False  False
# 813  False  False  False            False  False          False  False  False
# 814  False  False  False            False  False          False  False  False
# 815  False  False  False            False  False          False  False  False
#
# ...

# %%
df.isnull()
# Out:
#         id   city   date  player_of_match  venue  neutral_venue  team1  team2  \
# 0    False  False  False            False  False          False  False  False
# 1    False  False  False            False  False          False  False  False
# 2    False  False  False            False  False          False  False  False
# 3    False  False  False            False  False          False  False  False
# 4    False  False  False            False  False          False  False  False
# ..     ...    ...    ...              ...    ...            ...    ...    ...
# 811  False  False  False            False  False          False  False  False
# 812  False  False  False            False  False          False  False  False
# 813  False  False  False            False  False          False  False  False
# 814  False  False  False            False  False          False  False  False
# 815  False  False  False            False  False          False  False  False
#
# ...

# %%
df.isna().sum()
# Out:
# id                   0
# city                13
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
df.shape
# Out:
# (816, 17)

# %%
df.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
df.tail()
# Out:
#           id       city        date player_of_match  \
# 811  1216547      Dubai  2020-09-28  AB de Villiers
# 812  1237177      Dubai  2020-11-05       JJ Bumrah
# 813  1237178  Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180  Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181      Dubai  2020-11-10        TA Boult
#
#                                    venue  neutral_venue  \
# 811  Dubai International Cricket Stadium              0
# 812  Dubai International Cricket Stadium              0
# 813                 Sheikh Zayed Stadium              0
# 814                 Sheikh Zayed Stadium              0
# 815  Dubai International Cricket Stadium              0
#
#                            team1                team2          toss_winner  \
# 811  Royal Challengers Bangalore       Mumbai Indians       Mumbai Indians
# 812               Mumbai Indians       Delhi Capitals       Delhi Capitals
# 813  Royal Challengers Bangalore  Sunrisers Hyderabad  Sunrisers Hyderabad
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
df.dropna(inplace=False)
# Out:
#           id           city        date   player_of_match  \
# 40    336022          Delhi  2008-05-17  DPMD Jayawardene
# 43    336025        Kolkata  2008-05-18           M Ntini
# 60    392183      Cape Town  2009-04-19        DL Vettori
# 63    392186         Durban  2009-04-21          CH Gayle
# 89    392214      Centurion  2009-05-07         ML Hayden
# 192   501215          Kochi  2011-04-18       BB McCullum
# 221   501245        Kolkata  2011-05-07     Iqbal Abdulla
# 231   501255      Bangalore  2011-05-14          CH Gayle
# 429   733993          Delhi  2014-05-10          DW Steyn
# 477   829743  Visakhapatnam  2015-04-22         DA Warner
# 508   829807      Hyderabad  2015-05-15           V Kohli
# 538   980943      Hyderabad  2016-04-26          AB Dinda
# 561   980989        Kolkata  2016-05-14         YK Pathan
# 565   980997  Visakhapatnam  2016-05-17          AB Dinda
# 566   980999      Bangalore  2016-05-18           V Kohli
# ...

# %%
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.dtypes
# Out:
# id                   int64
# city                object
# date                object
# player_of_match     object
# venue               object
# neutral_venue        int64
# team1               object
# team2               object
# toss_winner         object
# toss_decision       object
# winner              object
# result              object
# result_margin      float64
# eliminator          object
# method              object
# umpire1             object
# umpire2             object
# dtype: object

# %%
df.std()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_6184\3390915376.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# id               305894.254804
# neutral_venue         0.292512
# result_margin        22.068427
# dtype: float64

# %%
df.mean()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_6184\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# id               756349.553922
# neutral_venue         0.094363
# result_margin        17.321652
# dtype: float64

# %%
df.median()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_6184\530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# id               729298.0
# neutral_venue         0.0
# result_margin         8.0
# dtype: float64

# %%
df["id"].max()
# Out:
# 1237181

# %%
df.loc[df["id"].idxmax()]
# Out:
# id                                             1237181
# city                                             Dubai
# date                                        2020-11-10
# player_of_match                               TA Boult
# venue              Dubai International Cricket Stadium
# neutral_venue                                        0
# team1                                   Delhi Capitals
# team2                                   Mumbai Indians
# toss_winner                             Delhi Capitals
# toss_decision                                      bat
# winner                                  Mumbai Indians
# result                                         wickets
# result_margin                                      5.0
# eliminator                                           N
# method                                             NaN
# umpire1                                    CB Gaffaney
# umpire2                                    Nitin Menon
# Name: 815, dtype: object

# %%
df1 = pd.get_dummies(df["toss_decision"])

# %%
df1
# Out:
#      bat  field
# 0      0      1
# 1      1      0
# 2      1      0
# 3      1      0
# 4      1      0
# ..   ...    ...
# 811    0      1
# 812    0      1
# 813    0      1
# 814    1      0
# 815    1      0
#
# [816 rows x 2 columns]

# %%
df_new = pd.concat([df,df1],axis=1)

# %%
df_new
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
import seaborn as sns

# %%
data = {"name":["A","B","C","D","E"],"age":[10,16,12,21,22],"marks":[96,92,None,98,94],"gender":["male","male","female","male","female"]}

# %%
dataframe = pd.DataFrame(data)

# %%
dataframe
# Out:
#   name  age  marks  gender
# 0    A   10   96.0    male
# 1    B   16   92.0    male
# 2    C   12    NaN  female
# 3    D   21   98.0    male
# 4    E   22   94.0  female

# %%
dataframe.isna()
# Out:
#     name    age  marks  gender
# 0  False  False  False   False
# 1  False  False  False   False
# 2  False  False   True   False
# 3  False  False  False   False
# 4  False  False  False   False

# %%
dataframe.isna().sum()
# Out:
# name      0
# age       0
# marks     1
# gender    0
# dtype: int64

# %%
dataframe.describe()
# Out:
#              age      marks
# count   5.000000   4.000000
# mean   16.200000  95.000000
# std     5.310367   2.581989
# min    10.000000  92.000000
# 25%    12.000000  93.500000
# 50%    16.000000  95.000000
# 75%    21.000000  96.500000
# max    22.000000  98.000000

# %%
dataframe.fillna(0)
# Out:
#   name  age  marks  gender
# 0    A   10   96.0    male
# 1    B   16   92.0    male
# 2    C   12    0.0  female
# 3    D   21   98.0    male
# 4    E   22   94.0  female

# %%
dataframe["marks"].mean()
# Out:
# 95.0

# %%
dataframe.loc[5] = ["F",18,120,"male"]

# %%
dataframe
# Out:
#   name  age  marks  gender
# 0    A   10   96.0    male
# 1    B   16   92.0    male
# 2    C   12    NaN  female
# 3    D   21   98.0    male
# 4    E   22   94.0  female
# 5    F   18  120.0    male

# %%
dataframe.loc[6] = ["G",20,56,"female"]

# %%
sns.countplot(data=dataframe,x="gender")
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
sns.boxplot(data=dataframe,x="marks")
# Out:
# <AxesSubplot:xlabel='marks'>

# %%
sns.histplot(data=dataframe,x="gender")
# Out:
# <AxesSubplot:xlabel='gender', ylabel='Count'>

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
dataframe[["marks"]] = scaler.fit_transform(dataframe[["marks"]])

# %%
dataframe
# Out:
#   name  age    marks  gender
# 0    A   10  0.62500    male
# 1    B   16  0.56250    male
# 2    C   12      NaN  female
# 3    D   21  0.65625    male
# 4    E   22  0.59375  female
# 5    F   18  1.00000    male
# 6    G   20  0.00000  female
