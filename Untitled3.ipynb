# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
data = [2, 2, 1, 0, 2, 0, 1, 0, 2, 0, 2, 1, 1, 1, 0, 1, 1, 1]
df = pd.DataFrame(dict(col1=np.array(data)))
sns.countplot(x="col1", data=df)
# Out:
# <AxesSubplot:xlabel='col1', ylabel='count'>
